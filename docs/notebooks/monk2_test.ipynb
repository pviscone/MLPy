# %%
project_dir = '../../'
data_dir = project_dir + 'data/'

import sys
sys.path.append(project_dir + 'NN/')

import numpy as np
import time
import matplotlib.pyplot as plt
from MLP import MLP

# %% [markdown]
# # Monk 2

# %%
def one_hot_encoding(input_matrix):
    numclass=np.max(input_matrix,axis=0)
    matrix=np.zeros((len(input_matrix),int(np.sum(numclass))))
    for idx_row,row in enumerate(input_matrix):
        for idx_column,value in enumerate(row):
            matrix[idx_row,int(np.sum(numclass[:idx_column]))+int(value)-1]=1
    return matrix

# %%
data_monk=np.loadtxt("../../data/MONK/monks-2.train",usecols=range(0,7))
labels=np.reshape(data_monk[:,0],(len(data_monk),1))
input_data=data_monk[:,1:]
input_data=one_hot_encoding(input_data)

data_monk_val=np.loadtxt("../../data/MONK/monks-2.test",usecols=range(0,7))
val_labels=np.reshape(data_monk_val[:,0],(len(data_monk_val),1))
val_data=data_monk_val[:,1:]
val_data=one_hot_encoding(val_data)

# %%
structure=[4,np.shape(labels)[1]]
act_func=[("sigmoid",1),("sigmoid",1)]
start=[0.3,0.3]

netw = MLP(structure, func=act_func,
           starting_points=start)

# %%
learning_rate=0.7
lamb=0.
N_epoch=1500
alpha=0.6
nesterov=False
batch_size=50
netw.train(input_data, labels, val_data, val_labels,
        epoch = N_epoch,eta = learning_rate, lamb = lamb,alpha=alpha,
        nesterov=nesterov,batch_size=batch_size)
# Out:
# Epoch 1500:  [train MEE = 0.0360]  [val MEE = 0.0390]
# Elapsed time: 2.3823258876800537 s

# %%
train_pred = netw.predict(input_data)
val_pred = netw.predict(val_data)
x = np.arange(len(netw.train_MEE))

h = 11
l = h*5/20
second_col = 'orange'#'orange'
monk_num = 2 # number of monk dataset


plt.figure(figsize=(h,l))
plt.subplot(121)
plt.plot(x,netw.train_MSE,label="training", lw = 0.8, c = 'black')
plt.plot(x,netw.val_MSE,label="test", lw = 1, c = second_col)
plt.title(f"Monk {monk_num} Learning curve")
plt.xlabel("Epochs",fontsize="large")
plt.ylabel("MSE",fontsize="large")
plt.grid(alpha = 0.4)
plt.legend(fontsize="large")

plt.subplot(122)
plt.plot(x,netw.train_accuracy,label="training", lw = 0.8, c = 'black')
plt.plot(x,netw.val_accuracy,label="test", lw = 1, c = second_col)
plt.title (f"Monk {monk_num} Accuracy")
plt.ylabel("Accuracy",fontsize="large")
plt.xlabel("Epochs",fontsize="large")
plt.legend(fontsize="large", loc = 'lower right')
plt.grid(alpha = 0.4)
plt.tight_layout()
if second_col == 'silver': name = f'monk{monk_num}_bg.png'
elif second_col == 'orange': name = f'monk{monk_num}_bo.png'
else: name = f'monk{monk_num}_unknow.png'
plt.savefig('../report/figures/MONK/' + name, dpi = 200)

# %%
accuracy_val=[]
accuracy_tr=[]
mse_tr=[]
mse_val=[]
for i in range(60):
        print("Try: ",i)
        netw = MLP(structure, func=act_func,
                starting_points=start)
        netw.train(input_data, labels, val_data, val_labels,
                epoch = N_epoch,eta = learning_rate, lamb = lamb,alpha=alpha,
                nesterov=nesterov,batch_size=batch_size,verbose=False)
        accuracy_val.append(netw.val_accuracy[-1])
        accuracy_tr.append(netw.train_accuracy[-1])
        mse_tr.append(netw.train_MSE[-1])
        mse_val.append(netw.val_MSE[-1])
        print("Accuracy: ",accuracy_val[-1])
        print("mean_std: ",np.mean(accuracy_val), " ", np.std(accuracy_val),"\n")
print(f"Accuracy_val: {np.mean(accuracy_val)} +- {np.std(accuracy_val)}\n Accuracy_tr: {np.mean(accuracy_tr)} +- {np.std(accuracy_tr)}\n MSE_tr: {np.mean(mse_tr)} +- {np.std(mse_tr)}\n MSE_val: {np.mean(mse_val)} +- {np.std(mse_val)}")
# Out:
# Try:  0
# Epoch 1500:  [train MEE = 0.0382]  [val MEE = 0.0407]
# Elapsed time: 1.6617114543914795 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  1
# Epoch 1500:  [train MEE = 0.0336]  [val MEE = 0.0360]
# Elapsed time: 1.6354382038116455 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  2
# Epoch 1500:  [train MEE = 0.0369]  [val MEE = 0.0392]
# Elapsed time: 1.6322882175445557 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  3
# Epoch 1500:  [train MEE = 0.0344]  [val MEE = 0.0381]
# Elapsed time: 1.6249091625213623 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  4
# Epoch 1500:  [train MEE = 0.0330]  [val MEE = 0.0355]
# Elapsed time: 1.6067471504211426 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  5
# Epoch 1500:  [train MEE = 0.0314]  [val MEE = 0.0337]
# Elapsed time: 1.6038284301757812 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  6
# Epoch 1500:  [train MEE = 0.0348]  [val MEE = 0.0387]
# Elapsed time: 1.5888097286224365 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  7
# Epoch 1500:  [train MEE = 0.0361]  [val MEE = 0.0384]
# Elapsed time: 1.6028435230255127 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  8
# Epoch 1500:  [train MEE = 0.0315]  [val MEE = 0.0337]
# Elapsed time: 1.5929882526397705 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  9
# Epoch 1500:  [train MEE = 0.0331]  [val MEE = 0.0355]
# Elapsed time: 1.589677095413208 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  10
# Epoch 1500:  [train MEE = 0.0332]  [val MEE = 0.0354]
# Elapsed time: 1.6008567810058594 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  11
# Epoch 1500:  [train MEE = 0.0335]  [val MEE = 0.0360]
# Elapsed time: 1.6453862190246582 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  12
# Epoch 1500:  [train MEE = 0.0332]  [val MEE = 0.0356]
# Elapsed time: 1.6250271797180176 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  13
# Epoch 1500:  [train MEE = 0.0323]  [val MEE = 0.0346]
# Elapsed time: 1.6094777584075928 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  14
# Epoch 1500:  [train MEE = 0.0377]  [val MEE = 0.0414]
# Elapsed time: 1.599191665649414 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  15
# Epoch 1500:  [train MEE = 0.0381]  [val MEE = 0.0412]
# Elapsed time: 1.6038765907287598 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  16
# Epoch 1500:  [train MEE = 0.0365]  [val MEE = 0.0390]
# Elapsed time: 1.5929534435272217 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  17
# Epoch 1500:  [train MEE = 0.0338]  [val MEE = 0.0364]
# Elapsed time: 1.5989325046539307 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  18
# Epoch 1500:  [train MEE = 0.0310]  [val MEE = 0.0338]
# Elapsed time: 1.5867414474487305 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  19
# Epoch 1500:  [train MEE = 0.0343]  [val MEE = 0.0371]
# Elapsed time: 1.5984246730804443 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  20
# Epoch 1500:  [train MEE = 0.0341]  [val MEE = 0.0375]
# Elapsed time: 1.6016650199890137 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  21
# Epoch 1500:  [train MEE = 0.0286]  [val MEE = 0.0311]
# Elapsed time: 1.584014654159546 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  22
# Epoch 1500:  [train MEE = 0.0330]  [val MEE = 0.0353]
# Elapsed time: 1.5909099578857422 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  23
# Epoch 1500:  [train MEE = 0.0394]  [val MEE = 0.0425]
# Elapsed time: 1.5947027206420898 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  24
# Epoch 1500:  [train MEE = 0.0384]  [val MEE = 0.0415]
# Elapsed time: 1.5890824794769287 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  25
# Epoch 1500:  [train MEE = 0.0349]  [val MEE = 0.0374]
# Elapsed time: 1.6149587631225586 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  26
# Epoch 1500:  [train MEE = 0.0296]  [val MEE = 0.0321]
# Elapsed time: 1.5921804904937744 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  27
# Epoch 1500:  [train MEE = 0.0332]  [val MEE = 0.0357]
# Elapsed time: 1.5908277034759521 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  28
# Epoch 1500:  [train MEE = 0.0322]  [val MEE = 0.0347]
# Elapsed time: 1.593440055847168 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  29
# Epoch 1500:  [train MEE = 0.0346]  [val MEE = 0.0373]
# Elapsed time: 1.600924015045166 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  30
# Epoch 1500:  [train MEE = 0.0316]  [val MEE = 0.0338]
# Elapsed time: 1.5899333953857422 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  31
# Epoch 1500:  [train MEE = 0.0323]  [val MEE = 0.0347]
# Elapsed time: 1.6015279293060303 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  32
# Epoch 1500:  [train MEE = 0.0332]  [val MEE = 0.0356]
# Elapsed time: 1.6025164127349854 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  33
# Epoch 1500:  [train MEE = 0.0318]  [val MEE = 0.0342]
# Elapsed time: 1.598207712173462 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  34
# Epoch 1500:  [train MEE = 0.0408]  [val MEE = 0.0452]
# Elapsed time: 1.5929961204528809 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  35
# Epoch 1500:  [train MEE = 0.0337]  [val MEE = 0.0362]
# Elapsed time: 1.5936498641967773 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  36
# Epoch 1500:  [train MEE = 0.0326]  [val MEE = 0.0349]
# Elapsed time: 1.6003291606903076 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  37
# Epoch 1500:  [train MEE = 0.0356]  [val MEE = 0.0390]
# Elapsed time: 1.5825631618499756 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  38
# Epoch 1500:  [train MEE = 0.0398]  [val MEE = 0.0438]
# Elapsed time: 1.5869793891906738 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  39
# Epoch 1500:  [train MEE = 0.0353]  [val MEE = 0.0378]
# Elapsed time: 1.6017792224884033 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  40
# Epoch 1500:  [train MEE = 0.0335]  [val MEE = 0.0362]
# Elapsed time: 1.586033582687378 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  41
# Epoch 1500:  [train MEE = 0.0348]  [val MEE = 0.0386]
# Elapsed time: 1.6120853424072266 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  42
# Epoch 1500:  [train MEE = 0.0333]  [val MEE = 0.0358]
# Elapsed time: 1.6137428283691406 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  43
# Epoch 1500:  [train MEE = 0.0345]  [val MEE = 0.0371]
# Elapsed time: 1.6273019313812256 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  44
# Epoch 1500:  [train MEE = 0.0348]  [val MEE = 0.0374]
# Elapsed time: 1.6211297512054443 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  45
# Epoch 1500:  [train MEE = 0.0332]  [val MEE = 0.0354]
# Elapsed time: 1.598276138305664 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  46
# Epoch 1500:  [train MEE = 0.0358]  [val MEE = 0.0397]
# Elapsed time: 1.6061375141143799 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  47
# Epoch 1500:  [train MEE = 0.0337]  [val MEE = 0.0375]
# Elapsed time: 1.6064183712005615 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  48
# Epoch 1500:  [train MEE = 0.0374]  [val MEE = 0.0409]
# Elapsed time: 1.5933287143707275 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  49
# Epoch 1500:  [train MEE = 0.0381]  [val MEE = 0.0403]
# Elapsed time: 1.6034533977508545 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  50
# Epoch 1500:  [train MEE = 0.0354]  [val MEE = 0.0380]
# Elapsed time: 1.5994970798492432 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  51
# Epoch 1500:  [train MEE = 0.0363]  [val MEE = 0.0384]
# Elapsed time: 1.5982706546783447 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  52
# Epoch 1500:  [train MEE = 0.0383]  [val MEE = 0.0415]
# Elapsed time: 1.5877125263214111 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  53
# Epoch 1500:  [train MEE = 0.0329]  [val MEE = 0.0353]
# Elapsed time: 1.595287799835205 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  54
# Epoch 1500:  [train MEE = 0.0344]  [val MEE = 0.0368]
# Elapsed time: 1.586806297302246 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  55
# Epoch 1500:  [train MEE = 0.0310]  [val MEE = 0.0333]
# Elapsed time: 1.5830895900726318 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  56
# Epoch 1500:  [train MEE = 0.0311]  [val MEE = 0.0335]
# Elapsed time: 1.5842869281768799 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  57
# Epoch 1500:  [train MEE = 0.0312]  [val MEE = 0.0335]
# Elapsed time: 1.6440773010253906 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  58
# Epoch 1500:  [train MEE = 0.0324]  [val MEE = 0.0348]
# Elapsed time: 1.6283600330352783 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  59
# Epoch 1500:  [train MEE = 0.0401]  [val MEE = 0.0445]
# Elapsed time: 1.6080644130706787 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Accuracy_val: 1.0 +- 0.0
#  Accuracy_tr: 1.0 +- 0.0
#  MSE_tr: 0.0013805275844888903 +- 0.00020722350700708077
#  MSE_val: 0.0016327099826998952 +- 0.0002764992196215569
