# %%
project_dir = '../../'
data_dir = project_dir + 'data/'

import sys
sys.path.append(project_dir + 'NN/')

import numpy as np
import time
import matplotlib.pyplot as plt
from MLP import MLP

# %% [markdown]
# # Monk 2

# %%
def one_hot_encoding(input_matrix):
    numclass=np.max(input_matrix,axis=0)
    matrix=np.zeros((len(input_matrix),int(np.sum(numclass))))
    for idx_row,row in enumerate(input_matrix):
        for idx_column,value in enumerate(row):
            matrix[idx_row,int(np.sum(numclass[:idx_column]))+int(value)-1]=1
    return matrix

# %%
data_monk=np.loadtxt("../../data/MONK/monks-2.train",usecols=range(0,7))
labels=np.reshape(data_monk[:,0],(len(data_monk),1))
input_data=data_monk[:,1:]
input_data=one_hot_encoding(input_data)

data_monk_val=np.loadtxt("../../data/MONK/monks-2.test",usecols=range(0,7))
val_labels=np.reshape(data_monk_val[:,0],(len(data_monk_val),1))
val_data=data_monk_val[:,1:]
val_data=one_hot_encoding(val_data)

# %%
structure=[4,np.shape(labels)[1]]
act_func=[("sigmoid",1),("sigmoid",1)]
start=[0.3,0.3]

netw = MLP(structure, func=act_func,
           starting_points=start)

# %%
learning_rate=0.8
lamb=0.
N_epoch=1000
alpha=0.8
nesterov=False
batch_size=10
netw.train(input_data, labels, val_data, val_labels,
        epoch = N_epoch,eta = learning_rate, lamb = lamb,alpha=alpha,
        nesterov=nesterov,batch_size=batch_size)
# Out:
# Epoch 1000:  [train MEE = 0.0132]  [val MEE = 0.0140]
# Elapsed time: 3.6468770503997803 s

# %%
train_pred = netw.predict(input_data)
val_pred = netw.predict(val_data)

x = np.arange(len(netw.train_MEE))

plt.figure(figsize=(15,5))
plt.subplot(121)
plt.plot(x,netw.train_MSE,label="training")
plt.plot(x,netw.val_MSE,"--",label="test")
plt.title("Monk 2 Learning curve")
plt.xlabel("Epochs",fontsize="large")
plt.ylabel("MSE",fontsize="large")
plt.grid()
plt.legend(fontsize="large")

plt.subplot(122)
plt.plot(x,netw.train_accuracy,label="training")
plt.plot(x,netw.val_accuracy,"--",label="test")
plt.title ("Monk 2 Accuracy")
plt.ylabel("Accuracy",fontsize="large")
plt.xlabel("Epochs",fontsize="large")
plt.legend(fontsize="large")
plt.grid()

# %%
accuracy=[]
mse_tr=[]
mse_val=[]

# %%
for i in range(60):
        print("Try: ",i)
        netw = MLP(structure, func=act_func,
                starting_points=start)
        netw.train(input_data, labels, val_data, val_labels,
                epoch = N_epoch,eta = learning_rate, lamb = lamb,alpha=alpha,
                nesterov=nesterov,batch_size=batch_size,verbose=False)
        accuracy.append(netw.val_accuracy[-1])
        mse_tr.append(netw.train_MSE[-1])
        mse_val.append(netw.val_MSE[-1])
        print("Accuracy: ",accuracy[-1])
        print("mean_std: ",np.mean(accuracy), " ", np.std(accuracy),"\n")
# Out:
# Try:  0
# Epoch 1000:  [train MEE = 0.0115]  [val MEE = 0.0125]
# Elapsed time: 2.0496490001678467 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  1
# Epoch 1000:  [train MEE = 0.0137]  [val MEE = 0.0147]
# Elapsed time: 2.057776689529419 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  2
# Epoch 1000:  [train MEE = 0.0130]  [val MEE = 0.0139]
# Elapsed time: 2.0760955810546875 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  3
# Epoch 1000:  [train MEE = 0.0133]  [val MEE = 0.0142]
# Elapsed time: 2.127284288406372 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  4
# Epoch 1000:  [train MEE = 0.0130]  [val MEE = 0.0143]
# Elapsed time: 2.0948052406311035 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  5
# Epoch 1000:  [train MEE = 0.0120]  [val MEE = 0.0130]
# Elapsed time: 2.1032726764678955 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  6
# Epoch 1000:  [train MEE = 0.0126]  [val MEE = 0.0135]
# Elapsed time: 2.094738721847534 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  7
# Epoch 1000:  [train MEE = 0.0147]  [val MEE = 0.0154]
# Elapsed time: 2.1010401248931885 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  8
# Epoch 1000:  [train MEE = 0.0135]  [val MEE = 0.0149]
# Elapsed time: 2.131267786026001 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  9
# Epoch 1000:  [train MEE = 0.0153]  [val MEE = 0.0165]
# Elapsed time: 2.1089975833892822 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  10
# Epoch 1000:  [train MEE = 0.0143]  [val MEE = 0.0152]
# Elapsed time: 2.1159214973449707 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  11
# Epoch 1000:  [train MEE = 0.0131]  [val MEE = 0.0139]
# Elapsed time: 2.107523202896118 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  12
# Epoch 1000:  [train MEE = 0.0148]  [val MEE = 0.0160]
# Elapsed time: 2.120765209197998 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  13
# Epoch 1000:  [train MEE = 0.0132]  [val MEE = 0.0141]
# Elapsed time: 2.1264796257019043 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  14
# Epoch 1000:  [train MEE = 0.0146]  [val MEE = 0.0154]
# Elapsed time: 2.124394178390503 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  15
# Epoch 1000:  [train MEE = 0.0135]  [val MEE = 0.0152]
# Elapsed time: 2.1143839359283447 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  16
# Epoch 1000:  [train MEE = 0.0130]  [val MEE = 0.0139]
# Elapsed time: 2.1703522205352783 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  17
# Epoch 1000:  [train MEE = 0.0130]  [val MEE = 0.0139]
# Elapsed time: 2.1336233615875244 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  18
# Epoch 1000:  [train MEE = 0.0148]  [val MEE = 0.0163]
# Elapsed time: 2.0439820289611816 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  19
# Epoch 1000:  [train MEE = 0.0130]  [val MEE = 0.0139]
# Elapsed time: 2.157743453979492 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  20
# Epoch 1000:  [train MEE = 0.0150]  [val MEE = 0.0159]
# Elapsed time: 2.0915307998657227 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  21
# Epoch 1000:  [train MEE = 0.0140]  [val MEE = 0.0150]
# Elapsed time: 2.143749237060547 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  22
# Epoch 1000:  [train MEE = 0.0145]  [val MEE = 0.0153]
# Elapsed time: 2.173276901245117 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  23
# Epoch 1000:  [train MEE = 0.0143]  [val MEE = 0.0151]
# Elapsed time: 2.082214593887329 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  24
# Epoch 1000:  [train MEE = 0.0128]  [val MEE = 0.0139]
# Elapsed time: 2.067451000213623 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  25
# Epoch 1000:  [train MEE = 0.0145]  [val MEE = 0.0159]
# Elapsed time: 2.0046286582946777 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  26
# Epoch 1000:  [train MEE = 0.0132]  [val MEE = 0.0140]
# Elapsed time: 2.011176824569702 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  27
# Epoch 1000:  [train MEE = 0.0149]  [val MEE = 0.0156]
# Elapsed time: 2.1477582454681396 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  28
# Epoch 1000:  [train MEE = 0.0129]  [val MEE = 0.0137]
# Elapsed time: 2.1403286457061768 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  29
# Epoch 1000:  [train MEE = 0.0142]  [val MEE = 0.0150]
# Elapsed time: 2.125275135040283 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  30
# Epoch 1000:  [train MEE = 0.0139]  [val MEE = 0.0149]
# Elapsed time: 2.1855757236480713 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  31
# Epoch 1000:  [train MEE = 0.0131]  [val MEE = 0.0140]
# Elapsed time: 2.016340970993042 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  32
# Epoch 1000:  [train MEE = 0.0135]  [val MEE = 0.0144]
# Elapsed time: 2.0425703525543213 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  33
# Epoch 1000:  [train MEE = 0.0144]  [val MEE = 0.0152]
# Elapsed time: 2.0640344619750977 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  34
# Epoch 1000:  [train MEE = 0.0132]  [val MEE = 0.0141]
# Elapsed time: 2.0240023136138916 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  35
# Epoch 1000:  [train MEE = 0.0138]  [val MEE = 0.0148]
# Elapsed time: 2.135561466217041 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  36
# Epoch 1000:  [train MEE = 0.0131]  [val MEE = 0.0140]
# Elapsed time: 2.1400864124298096 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  37
# Epoch 1000:  [train MEE = 0.0131]  [val MEE = 0.0146]
# Elapsed time: 2.154719352722168 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  38
# Epoch 1000:  [train MEE = 0.0130]  [val MEE = 0.0139]
# Elapsed time: 2.1179819107055664 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  39
# Epoch 1000:  [train MEE = 0.0141]  [val MEE = 0.0150]
# Elapsed time: 2.1273388862609863 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  40
# Epoch 1000:  [train MEE = 0.0145]  [val MEE = 0.0154]
# Elapsed time: 2.109527587890625 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  41
# Epoch 1000:  [train MEE = 0.0131]  [val MEE = 0.0140]
# Elapsed time: 2.1291427612304688 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  42
# Epoch 1000:  [train MEE = 0.0130]  [val MEE = 0.0139]
# Elapsed time: 2.1421313285827637 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  43
# Epoch 1000:  [train MEE = 0.0130]  [val MEE = 0.0139]
# Elapsed time: 2.1656267642974854 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  44
# Epoch 1000:  [train MEE = 0.0136]  [val MEE = 0.0145]
# Elapsed time: 2.168088912963867 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  45
# Epoch 1000:  [train MEE = 0.0130]  [val MEE = 0.0139]
# Elapsed time: 2.158789873123169 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  46
# Epoch 1000:  [train MEE = 0.0139]  [val MEE = 0.0151]
# Elapsed time: 2.202435255050659 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  47
# Epoch 1000:  [train MEE = 0.0133]  [val MEE = 0.0142]
# Elapsed time: 2.169691562652588 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  48
# Epoch 1000:  [train MEE = 0.0120]  [val MEE = 0.0131]
# Elapsed time: 2.171677589416504 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  49
# Epoch 1000:  [train MEE = 0.0117]  [val MEE = 0.0127]
# Elapsed time: 2.1771249771118164 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  50
# Epoch 1000:  [train MEE = 0.0130]  [val MEE = 0.0139]
# Elapsed time: 2.2247238159179688 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  51
# Epoch 1000:  [train MEE = 0.0142]  [val MEE = 0.0152]
# Elapsed time: 2.1199753284454346 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  52
# Epoch 1000:  [train MEE = 0.0128]  [val MEE = 0.0137]
# Elapsed time: 2.166144609451294 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  53
# Epoch 1000:  [train MEE = 0.0115]  [val MEE = 0.0124]
# Elapsed time: 2.1959681510925293 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  54
# Epoch 1000:  [train MEE = 0.0130]  [val MEE = 0.0142]
# Elapsed time: 2.1161906719207764 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  55
# Epoch 1000:  [train MEE = 0.0128]  [val MEE = 0.0137]
# Elapsed time: 2.1165084838867188 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  56
# Epoch 1000:  [train MEE = 0.0132]  [val MEE = 0.0141]
# Elapsed time: 2.1247377395629883 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  57
# Epoch 1000:  [train MEE = 0.0134]  [val MEE = 0.0143]
# Elapsed time: 2.1506965160369873 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  58
# Epoch 1000:  [train MEE = 0.0140]  [val MEE = 0.0149]
# Elapsed time: 2.091712713241577 s
# Accuracy:  1.0
# mean_std:  1.0   0.0
#
# Try:  59
# Epoch 1000:  [train MEE = 0.0129]  [val MEE = 0.0138]
# Elapsed time: 2.082315683364868 s
# Accuracy:  1.0
# mean_std:  1.0   0.0

# %%
print(f"Accuracy: {np.mean(accuracy)} +- {np.std(accuracy)}\n MSE_tr: {np.mean(mse_tr)} +- {np.std(mse_tr)}\n MSE_val: {np.mean(mse_val)} +- {np.std(mse_val)}")
# Out:
# Accuracy: 1.0 +- 0.0
#  MSE_tr: 0.00021140380531223262 +- 2.4479350646319395e-05
#  MSE_val: 0.00024548374959054947 +- 2.9155396965073075e-05
